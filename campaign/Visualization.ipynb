# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Alekhya Reddy\Desktop\airisData\campaign\input.txt",nrows=15)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Each_Item    15 non-null     object
#  1   Amount_Paid  15 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 368.0+ bytes

# %%
plt.plot(df.Each_Item,df.Amount_Paid,marker='*',markersize=4)

plt.title("Amount Paid for Each Item\n", fontdict={'fontsize': 20, 'fontweight' : 5, 'color' : 'Green'})

# Labeling Axes
plt.xlabel("Each_Item", fontdict={'fontsize': 12, 'fontweight' : 5, 'color' : 'Brown'})
plt.ylabel("Amount_Paid", fontdict={'fontsize': 12, 'fontweight' : 5, 'color' : 'Brown'} )
plt.gcf().set_size_inches(15,5)
plt.savefig(r"C:\Users\Alekhya Reddy\Desktop\airisData\campaign\PlotImages\output.jpg")
plt.show()
